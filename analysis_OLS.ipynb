# %%
df = pd.read_csv("datas/master_table.csv")

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c42a15b2c7cf> in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# year            0
# month           0
# quarter         0
# WeekDay         0
# Weekend         0
# Home            1
# Result          3
# Away            0
# etc             0
# Time          100
# Park            0
# Shiny           0
# Rain            0
# Min_c           0
# Max_c           0
# NO2            45
# O3             45
# CO             45
# SO2            45
# PM10           45
# PM25           45
# attendance      0
# dtype: int64

# %%
df = df.fillna(value = 0)

# %%
df.tail()
# Out:
#      year  month  quarter WeekDay  Weekend Home Result     Away etc     Time  \
# 411  2019      9        3       금        1   두산    win      KIA   -   13:30
# 412  2019      9        3       일        1   LG   lose       SK   -   18:30
# 413  2019      9        3       월        0    0     LG  SK<span   -   18:30
# 414  2019      9        3       금        0   두산   lose       롯데   -   17:00
# 415  2019      9        3       화        0   두산    win       삼성   -   18:30
#
#      ... Rain  Min_c  Max_c    NO2     O3   CO    SO2  PM10  PM25  attendance
# 411  ...  1.0   18.0   29.0  0.013  0.028  0.3  0.002  11.0   5.0       12415
# 412  ...  0.0   20.0   30.0  0.012  0.029  0.5  0.002  13.0   8.0       18171
# 413  ...  0.0   21.0   31.0  0.018  0.022  0.4  0.002  10.0   5.0        9298
# 414  ...  0.0   16.0   24.0  0.024  0.014  0.4  0.002  22.0   8.0       13147
# 415  ...  0.0   14.0   27.0  0.034  0.016  0.5  0.003  24.0  12.0       15115
#
# [5 rows x 22 columns]

# %%
df.to_csv("kbo_datas.csv", index=False)

# %%
model = sm.OLS.from_formula("attendance ~ C(WeekDay) + C(Weekend) + Shiny + Rain + Min_c + Max_c + NO2 + O3 + CO + SO2 + PM10 + PM25 + C(Away) + C(Home) + C(Result) + C(Time)", data=df)

# %%
result = model.fit()

# %%
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             attendance   R-squared:                       0.816
# Model:                            OLS   Adj. R-squared:                  0.796
# Method:                 Least Squares   F-statistic:                     40.45
# Date:                Mon, 09 Dec 2019   Prob (F-statistic):          6.77e-113
# Time:                        16:29:04   Log-Likelihood:                -3832.1
# No. Observations:                 416   AIC:                             7748.
# Df Residuals:                     374   BIC:                             7917.
# Df Model:                          41
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           6877.3693   1149.515      5.983      0.000    4617.047    9137.692
# ...

# %%
model2 = sm.OLS.from_formula("attendance ~ C(WeekDay) + C(Weekend) + Shiny + Rain + C(Away) + C(Home) + C(Result) + C(Time)", data=df)
result2 = model2.fit()
print(result2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             attendance   R-squared:                       0.799
# Model:                            OLS   Adj. R-squared:                  0.781
# Method:                 Least Squares   F-statistic:                     45.93
# Date:                Mon, 09 Dec 2019   Prob (F-statistic):          2.80e-112
# Time:                        16:29:26   Log-Likelihood:                -3850.8
# No. Observations:                 416   AIC:                             7770.
# Df Residuals:                     382   BIC:                             7907.
# Df Model:                          33
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept           7235.4390   1046.696      6.913      0.000    5177.432    9293.446
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
dfX = df.drop(["attendance"], axis=1)

# %%
dfX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 21 columns):
# year       416 non-null int64
# month      416 non-null int64
# quarter    416 non-null int64
# WeekDay    416 non-null object
# Weekend    416 non-null int64
# Home       416 non-null object
# Result     416 non-null object
# Away       416 non-null object
# etc        416 non-null object
# Time       416 non-null object
# Park       416 non-null object
# Shiny      416 non-null float64
# Rain       416 non-null float64
# Min_c      416 non-null float64
# Max_c      416 non-null float64
# NO2        416 non-null float64
# O3         416 non-null float64
# CO         416 non-null float64
# SO2        416 non-null float64
# PM10       416 non-null float64
# PM25       416 non-null float64
# dtypes: float64(10), int64(4), object(7)
# memory usage: 68.4+ KB
